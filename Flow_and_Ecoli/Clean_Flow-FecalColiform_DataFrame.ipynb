# %%
import pandas as pd

# %%
flow_csv = "Flow_Rate_Instantaneous_1972-2012.csv"
fecal_coli_csv = "Fecal_Coliform_1972-2012.csv"


flow_df = pd.read_csv(flow_csv)
fecal_df = pd.read_csv(fecal_coli_csv)

flo_df.head()
# Out:
#   OrganizationIdentifier            OrganizationFormalName  \
# 0                USGS-AK  USGS Alaska Water Science Center
# 1                USGS-AK  USGS Alaska Water Science Center
# 2                USGS-AK  USGS Alaska Water Science Center
# 3                USGS-AK  USGS Alaska Water Science Center
# 4                USGS-AK  USGS Alaska Water Science Center
#
#    ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 0  nwisak.01.99200062            5/7/92               21:40:00
# 1  nwisak.01.97600332           7/15/76               13:30:00
# 2  nwisak.01.97800591           8/24/78                9:30:00
# 3  nwisak.01.97600358            7/6/76               22:00:00
# 4  nwisak.01.97600359            7/7/76               10:00:00
#
#   ActivityStartTime/TimeZoneCode MonitoringLocationIdentifier  \
# 0                           AKDT                USGS-15275038
# 1                           AKDT         USGS-531500168214501
# ...

# %%
flow_df.columns
# Out:
# Index(['OrganizationIdentifier', 'OrganizationFormalName',
#        'ActivityIdentifier', 'ActivityStartDate', 'ActivityStartTime/Time',
#        'ActivityStartTime/TimeZoneCode', 'MonitoringLocationIdentifier',
#        'ResultIdentifier', 'DataLoggerLine', 'ResultDetectionConditionText',
#        'MethodSpecificationName', 'CharacteristicName',
#        'ResultSampleFractionText', 'ResultMeasureValue',
#        'ResultMeasure/MeasureUnitCode', 'MeasureQualifierCode',
#        'ResultStatusIdentifier', 'StatisticalBaseCode', 'ResultValueTypeName',
#        'ResultWeightBasisText', 'ResultTimeBasisText',
#        'ResultTemperatureBasisText', 'ResultParticleSizeBasisText',
#        'PrecisionValue', 'DataQuality/BiasValue', 'ConfidenceIntervalValue',
#        'UpperConfidenceLimitValue', 'LowerConfidenceLimitValue',
#        'ResultCommentText', 'USGSPCode',
#        'ResultDepthHeightMeasure/MeasureValue',
#        'ResultDepthHeightMeasure/MeasureUnitCode',
# ...

# %%
clean_flow_df = flow_df.dropna(axis=1, how='all')
clean_flow_df
# Out:
#       OrganizationIdentifier             OrganizationFormalName  \
# 0                    USGS-AK   USGS Alaska Water Science Center
# 1                    USGS-AK   USGS Alaska Water Science Center
# 2                    USGS-AK   USGS Alaska Water Science Center
# 3                    USGS-AK   USGS Alaska Water Science Center
# 4                    USGS-AK   USGS Alaska Water Science Center
# 5                    USGS-AK   USGS Alaska Water Science Center
# 6                    USGS-AK   USGS Alaska Water Science Center
# 7                    USGS-AK   USGS Alaska Water Science Center
# 8                    USGS-AK   USGS Alaska Water Science Center
# 9                    USGS-AK   USGS Alaska Water Science Center
# 10                   USGS-AK   USGS Alaska Water Science Center
# 11                   USGS-AK   USGS Alaska Water Science Center
# 12                   USGS-AK   USGS Alaska Water Science Center
# 13                   USGS-AK   USGS Alaska Water Science Center
# ...

# %%
clean_flow_df.columns
# Out:
# Index(['OrganizationIdentifier', 'OrganizationFormalName',
#        'ActivityIdentifier', 'ActivityStartDate', 'ActivityStartTime/Time',
#        'ActivityStartTime/TimeZoneCode', 'MonitoringLocationIdentifier',
#        'ResultIdentifier', 'ResultDetectionConditionText',
#        'CharacteristicName', 'ResultMeasureValue',
#        'ResultMeasure/MeasureUnitCode', 'ResultStatusIdentifier',
#        'StatisticalBaseCode', 'ResultValueTypeName', 'PrecisionValue',
#        'ResultCommentText', 'USGSPCode',
#        'ResultAnalyticalMethod/MethodIdentifier',
#        'ResultAnalyticalMethod/MethodIdentifierContext',
#        'ResultAnalyticalMethod/MethodName', 'LaboratoryName',
#        'AnalysisStartDate', 'ResultLaboratoryCommentText', 'ProviderName'],
#       dtype='object')

# %%
new_flow_df = clean_flow_df[['OrganizationIdentifier', 'OrganizationFormalName',
       'ActivityIdentifier', 'ActivityStartDate', 'ActivityStartTime/Time',
       'ActivityStartTime/TimeZoneCode', 'MonitoringLocationIdentifier',
       'ResultIdentifier','CharacteristicName', 'ResultMeasureValue',
       'ResultMeasure/MeasureUnitCode', 'ResultStatusIdentifier', 'ResultValueTypeName','USGSPCode','ProviderName']]
                            
new_flow_df
# Out:
#       OrganizationIdentifier             OrganizationFormalName  \
# 0                    USGS-AK   USGS Alaska Water Science Center
# 1                    USGS-AK   USGS Alaska Water Science Center
# 2                    USGS-AK   USGS Alaska Water Science Center
# 3                    USGS-AK   USGS Alaska Water Science Center
# 4                    USGS-AK   USGS Alaska Water Science Center
# 5                    USGS-AK   USGS Alaska Water Science Center
# 6                    USGS-AK   USGS Alaska Water Science Center
# 7                    USGS-AK   USGS Alaska Water Science Center
# 8                    USGS-AK   USGS Alaska Water Science Center
# 9                    USGS-AK   USGS Alaska Water Science Center
# 10                   USGS-AK   USGS Alaska Water Science Center
# 11                   USGS-AK   USGS Alaska Water Science Center
# 12                   USGS-AK   USGS Alaska Water Science Center
# 13                   USGS-AK   USGS Alaska Water Science Center
# ...

# %%
clean_new_flow_df = new_flow_df.dropna(axis=0, how='any')
clean_new_flow_df
# Out:
#       OrganizationIdentifier             OrganizationFormalName  \
# 0                    USGS-AK   USGS Alaska Water Science Center
# 1                    USGS-AK   USGS Alaska Water Science Center
# 2                    USGS-AK   USGS Alaska Water Science Center
# 3                    USGS-AK   USGS Alaska Water Science Center
# 4                    USGS-AK   USGS Alaska Water Science Center
# 5                    USGS-AK   USGS Alaska Water Science Center
# 6                    USGS-AK   USGS Alaska Water Science Center
# 7                    USGS-AK   USGS Alaska Water Science Center
# 8                    USGS-AK   USGS Alaska Water Science Center
# 9                    USGS-AK   USGS Alaska Water Science Center
# 10                   USGS-AK   USGS Alaska Water Science Center
# 11                   USGS-AK   USGS Alaska Water Science Center
# 12                   USGS-AK   USGS Alaska Water Science Center
# 13                   USGS-AK   USGS Alaska Water Science Center
# ...

# %%
clean_new_flow_df.to_csv("Clean_Flow_Data.csv", index=False)

# %%
fecal_df.head()
# Out:
#   OrganizationIdentifier            OrganizationFormalName  \
# 0                USGS-AK  USGS Alaska Water Science Center
# 1                USGS-AK  USGS Alaska Water Science Center
# 2                USGS-AK  USGS Alaska Water Science Center
# 3                USGS-AK  USGS Alaska Water Science Center
# 4                USGS-AK  USGS Alaska Water Science Center
#
#    ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 0  nwisak.01.97500013           8/16/75               17:00:00
# 1  nwisak.01.97600007          10/20/75               17:00:00
# 2  nwisak.01.97600009            6/3/76               15:00:00
# 3  nwisak.01.97700011           4/22/77               12:00:00
# 4  nwisak.01.97700013           6/13/77               16:30:00
#
#   ActivityStartTime/TimeZoneCode MonitoringLocationIdentifier  \
# 0                           AKDT                USGS-15024800
# 1                           AKDT                USGS-15024800
# ...

# %%
clean_fecal_df = fecal_df.dropna(axis=1, how='all')
clean_fecal_df
# Out:
#         OrganizationIdentifier  \
# 0                      USGS-AK
# 1                      USGS-AK
# 2                      USGS-AK
# 3                      USGS-AK
# 4                      USGS-AK
# 5                      USGS-AK
# 6                      USGS-AK
# 7                      USGS-AK
# 8                      USGS-AK
# 9                      USGS-AK
# 10                     USGS-AK
# 11                     USGS-AK
# 12                     USGS-AK
# 13                     USGS-AK
# 14                     USGS-AK
# 15                     USGS-AK
# 16                     USGS-AK
# 17                     USGS-AK
# 18                     USGS-AK
# 19                     USGS-AK
# 20                     USGS-AK
# 21                     USGS-AK
# 22                     USGS-AK
# 23                     USGS-AK
# 24                     USGS-AK
# 25                     USGS-AK
# 26                     USGS-AK
# 27                     USGS-AK
# 28                     USGS-AK
# ...

# %%
clean_fecal_df.columns
# Out:
# Index(['OrganizationIdentifier', 'OrganizationFormalName',
#        'ActivityIdentifier', 'ActivityStartDate', 'ActivityStartTime/Time',
#        'ActivityStartTime/TimeZoneCode', 'MonitoringLocationIdentifier',
#        'ResultIdentifier', 'ResultDetectionConditionText',
#        'CharacteristicName', 'ResultSampleFractionText', 'ResultMeasureValue',
#        'ResultMeasure/MeasureUnitCode', 'MeasureQualifierCode',
#        'ResultStatusIdentifier', 'StatisticalBaseCode', 'ResultValueTypeName',
#        'ResultWeightBasisText', 'ResultTimeBasisText',
#        'ResultTemperatureBasisText', 'PrecisionValue', 'ResultCommentText',
#        'USGSPCode', 'ResultAnalyticalMethod/MethodIdentifier',
#        'ResultAnalyticalMethod/MethodIdentifierContext',
#        'ResultAnalyticalMethod/MethodName', 'ResultAnalyticalMethod/MethodUrl',
#        'ResultAnalyticalMethod/MethodQualifierTypeName',
#        'MethodDescriptionText', 'LaboratoryName', 'AnalysisStartDate',
# ...

# %%
new_fecal_df = clean_fecal_df[['OrganizationIdentifier', 'OrganizationFormalName',
       'ActivityIdentifier', 'ActivityStartDate', 'ActivityStartTime/Time',
       'ActivityStartTime/TimeZoneCode', 'MonitoringLocationIdentifier',
       'ResultIdentifier','CharacteristicName','ResultMeasureValue',
       'ResultMeasure/MeasureUnitCode','ResultStatusIdentifier','ResultValueTypeName','USGSPCode','ProviderName']]

new_fecal_df
# Out:
#         OrganizationIdentifier  \
# 0                      USGS-AK
# 1                      USGS-AK
# 2                      USGS-AK
# 3                      USGS-AK
# 4                      USGS-AK
# 5                      USGS-AK
# 6                      USGS-AK
# 7                      USGS-AK
# 8                      USGS-AK
# 9                      USGS-AK
# 10                     USGS-AK
# 11                     USGS-AK
# 12                     USGS-AK
# 13                     USGS-AK
# 14                     USGS-AK
# 15                     USGS-AK
# 16                     USGS-AK
# 17                     USGS-AK
# 18                     USGS-AK
# 19                     USGS-AK
# 20                     USGS-AK
# 21                     USGS-AK
# 22                     USGS-AK
# 23                     USGS-AK
# 24                     USGS-AK
# 25                     USGS-AK
# 26                     USGS-AK
# 27                     USGS-AK
# 28                     USGS-AK
# ...

# %%
clean_new_fecal_df = new_fecal_df.dropna(axis=0, how='any')
clean_new_fecal_df
# Out:
#        OrganizationIdentifier             OrganizationFormalName  \
# 3                     USGS-AK   USGS Alaska Water Science Center
# 4                     USGS-AK   USGS Alaska Water Science Center
# 5                     USGS-AK   USGS Alaska Water Science Center
# 6                     USGS-AK   USGS Alaska Water Science Center
# 7                     USGS-AK   USGS Alaska Water Science Center
# 8                     USGS-AK   USGS Alaska Water Science Center
# 9                     USGS-AK   USGS Alaska Water Science Center
# 10                    USGS-AK   USGS Alaska Water Science Center
# 11                    USGS-AK   USGS Alaska Water Science Center
# 12                    USGS-AK   USGS Alaska Water Science Center
# 13                    USGS-AK   USGS Alaska Water Science Center
# 14                    USGS-AK   USGS Alaska Water Science Center
# 15                    USGS-AK   USGS Alaska Water Science Center
# ...

# %%
clean_new_fecal_df.to_csv("Clean_Fecal_Coliform_Data.csv", index=False)
