# %%
import pandas as pd
import numpy as np

# %%
turb12_file = "Turbidity_2012.csv"
turb82_file = "Turbidity_1982.csv"
temp12_pd = pd.read_csv(turb12_file)
temp82_pd = pd.read_csv(turb82_file)
temp12_pd.head()
# Out:
#   OrganizationIdentifier              OrganizationFormalName  \
# 0                    ARS  USDA Agricultural Research Service
# 1                    ARS  USDA Agricultural Research Service
# 2                    ARS  USDA Agricultural Research Service
# 3                    ARS  USDA Agricultural Research Service
# 4                    ARS  USDA Agricultural Research Service
#
#   ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 0   MSBL101_20120109        2012-01-09               00:00:00
# 1   MSBL101_20120123        2012-01-23               00:00:00
# 2   MSBL101_20120206        2012-02-06               00:00:00
# 3   MSBL101_20120221        2012-02-21               00:00:00
# 4   MSBL101_20120305        2012-03-05               00:00:00
#
#   ActivityStartTime/TimeZoneCode MonitoringLocationIdentifier  \
# 0                            CST             ARS-MSBL-MSBL101
# 1                            CST             ARS-MSBL-MSBL101
# 2                            CST             ARS-MSBL-MSBL101
# 3                            CST             ARS-MSBL-MSBL101
# 4                            CST             ARS-MSBL-MSBL101
#
#    ResultIdentifier DataLoggerLine ResultDetectionConditionText  ...  \
# 0  STEWARDS-1004375            NaN                          NaN  ...
# 1   STEWARDS-980827            NaN                          NaN  ...
# 2   STEWARDS-981752            NaN                          NaN  ...
# 3  STEWARDS-1004457            NaN                          NaN  ...
# 4   STEWARDS-981682            NaN                          NaN  ...
#
#    AnalysisEndTime/TimeZoneCode ResultLaboratoryCommentCode  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#   ResultLaboratoryCommentText ResultDetectionQuantitationLimitUrl  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
#
#   LaboratoryAccreditationIndicator LaboratoryAccreditationAuthorityName  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#   TaxonomistAccreditationIndicator TaxonomistAccreditationAuthorityName  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#   LabSamplePreparationUrl ProviderName
# 0                     NaN     STEWARDS
# 1                     NaN     STEWARDS
# 2                     NaN     STEWARDS
# 3                     NaN     STEWARDS
# 4                     NaN     STEWARDS
#
# [5 rows x 78 columns]

# %%
temp_12 = temp12_pd[["MonitoringLocationIdentifier","ActivityStartDate","CharacteristicName","ResultMeasureValue","ResultMeasure/MeasureUnitCode" ]]
temp_82 = temp82_pd[["MonitoringLocationIdentifier","ActivityStartDate","CharacteristicName","ResultMeasureValue","ResultMeasure/MeasureUnitCode" ]]

# %%
temp_82.head()
# Out:
#   MonitoringLocationIdentifier ActivityStartDate CharacteristicName  \
# 0                USGS-15024800        1982-05-28          Turbidity
# 1                USGS-15024800        1982-08-31          Turbidity
# 2                USGS-15024800        1982-10-12          Turbidity
# 3                USGS-15056100        1982-03-15          Turbidity
# 4                USGS-15056100        1982-05-25          Turbidity
#
#   ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0                 23                           NTU
# 1                270                           NTU
# 2                 70                           NTU
# 3                0.3                           NTU
# 4                2.7                           NTU

# %%
cleaned_temp12 = temp_12.dropna(how="any")
cleaned_temp82 = temp_82.dropna(how="any")

# %%
num_temp12 = cleaned_temp12
num_temp82 = cleaned_temp82
num_temp82.head()
# Out:
#   MonitoringLocationIdentifier ActivityStartDate CharacteristicName  \
# 0                USGS-15024800        1982-05-28          Turbidity
# 1                USGS-15024800        1982-08-31          Turbidity
# 2                USGS-15024800        1982-10-12          Turbidity
# 3                USGS-15056100        1982-03-15          Turbidity
# 4                USGS-15056100        1982-05-25          Turbidity
#
#   ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0                 23                           NTU
# 1                270                           NTU
# 2                 70                           NTU
# 3                0.3                           NTU
# 4                2.7                           NTU

# %%
num_temp12["Result"] = pd.to_numeric(cleaned_temp12["ResultMeasureValue"],'coerce')
num_temp82["Result"] = pd.to_numeric(cleaned_temp82["ResultMeasureValue"],'coerce')
# Out:
# C:\Users\phayes\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\phayes\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
grouped_12 = num_temp12.groupby(["MonitoringLocationIdentifier"])
grouped_82 = num_temp82.groupby(["MonitoringLocationIdentifier"])
mean_by_ID = grouped_12["Result"].mean()
mean_by_ID2 = grouped_82["Result"].mean()
mean_pd = pd.DataFrame(mean_by_ID)
mean_pd2 = pd.DataFrame(mean_by_ID2)
mean_pd2.head()
# Out:
#                               Result
# MonitoringLocationIdentifier
# 11NPSWRD_WQX-BISC_CSA_PPB       1.35
# 11NPSWRD_WQX-BISC_CSA_PPD       1.20
# 11NPSWRD_WQX-BISC_CSA_PPE       1.30
# 11NPSWRD_WQX-BISO_NPS_BN-1      1.40
# 11NPSWRD_WQX-BISO_NPS_BN-3      1.75

# %%
cleaned_mean = mean_pd.dropna(how="any")
cleaned_mean2 = mean_pd2.dropna(how="any")

cleaned_mean.to_csv("Mean_by_ID_2012.csv",index=True, header=True)
cleaned_mean2.to_csv("Mean_by_ID_1982.csv",index=True, header=True)
